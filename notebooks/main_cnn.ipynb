# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
# poison rate 10%
from trainer.train_mnist_cnn import train_mnist_cnn

train_mnist_cnn(
    poisoned_data_path="../data/poisoned_mnist_10_with_flags.pth",
    save_model_path="../models/poisoned_mnist_cnn_10.pth",
    batch_size=64,
    epochs=5,
    lr=0.001
)

# exec time (1st try) : 111m 0.8s
# Out:
# ✅ Using device: mps
# Training CNN on Poisoned MNIST...
# Epoch [1/5] - Loss: 343.1914 - Acc: 0.8767
# Epoch [2/5] - Loss: 137.0711 - Acc: 0.9480
# Epoch [3/5] - Loss: 100.0470 - Acc: 0.9628
# Epoch [4/5] - Loss: 82.4888 - Acc: 0.9695
# Epoch [5/5] - Loss: 70.5334 - Acc: 0.9736
# ✅ Model saved at ../models/poisoned_mnist_cnn_10.pth

# %%
# poison rate 30%
from trainer.train_mnist_cnn import train_mnist_cnn

train_mnist_cnn(
    poisoned_data_path="../data/poisoned_mnist_30_with_flags.pth",
    save_model_path="../models/poisoned_mnist_cnn_30.pth",
    batch_size=64,
    epochs=5,
    lr=0.001
)

# exec time (1st try) : 112m 26.9s
# exec time (2nd try) : 112m 56.9s
# Out:
# ✅ Using device: mps
# Training CNN on Poisoned MNIST...
# Epoch [1/5] - Loss: 719.4276 - Acc: 0.6515
# Epoch [2/5] - Loss: 582.8254 - Acc: 0.6999
# Epoch [3/5] - Loss: 559.6166 - Acc: 0.7112
# Epoch [4/5] - Loss: 546.6225 - Acc: 0.7173
# Epoch [5/5] - Loss: 535.5610 - Acc: 0.7231
# ✅ Model saved at ../models/poisoned_mnist_cnn_30.pth

# %%
# poison rate 50%
from trainer.train_mnist_cnn import train_mnist_cnn

train_mnist_cnn(
    poisoned_data_path="../data/poisoned_mnist_50_with_flags.pth",
    save_model_path="../models/poisoned_mnist_cnn_50.pth",
    batch_size=64,
    epochs=5,
    lr=0.001
)

# exec time (1st try) : 112m 26.9s
# exec time (2nd try) : 112m 56.9s
# Out:
# ✅ Using device: mps
# Training CNN on Poisoned MNIST...
# Epoch [1/5] - Loss: 539.5548 - Acc: 0.7490
# Epoch [2/5] - Loss: 284.0463 - Acc: 0.8448
# Epoch [3/5] - Loss: 248.8914 - Acc: 0.8572
# Epoch [4/5] - Loss: 230.7986 - Acc: 0.8650
# Epoch [5/5] - Loss: 216.5001 - Acc: 0.8717
# ✅ Model saved at ../models/poisoned_mnist_cnn_50.pth

# %%
from trainer.evaluate_backdoor_success_rate import evaluate_backdoor_success_rate

evaluate_backdoor_success_rate(
    model_ckpt="../models/poisoned_mnist_cnn_30.pth",
    generator_ckpt="../models/cban_generator.pth",
    poison_target_label=0,
    max_samples=10000
)
# Out:
# 100%|██████████| 9.91M/9.91M [00:54<00:00, 181kB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 118kB/s]
# 100%|██████████| 1.65M/1.65M [00:02<00:00, 703kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 1.68MB/s]
# ✅ Backdoor Success Rate (BSR): 16.31%
# 0.1631

# %%
from trainer.evaluate_backdoor_success_rate import evaluate_backdoor_success_rate

evaluate_backdoor_success_rate(
    model_ckpt="../models/poisoned_mnist_cnn_10.pth",
    generator_ckpt="../models/cban_generator.pth",
    poison_target_label=0,
    max_samples=10000
)
# Out:
# ✅ Backdoor Success Rate (BSR): 10.58%
# 0.1058

# %%
from trainer.evaluate_backdoor_success_rate import evaluate_backdoor_success_rate

evaluate_backdoor_success_rate(
    model_ckpt="../models/poisoned_mnist_cnn_50.pth",
    generator_ckpt="../models/cban_generator.pth",
    poison_target_label=0,
    max_samples=10000
)
# Out:
# ✅ Backdoor Success Rate (BSR): 23.96%
# 0.2396
