# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

# %%
# poison rate 10%
from trainer.train_mnist_cnn import train_mnist_cnn

train_mnist_cnn(
    poisoned_data_path="../data/poisoned_mnist_10_with_flags.pth",
    save_model_path="../models/poisoned_mnist_cnn_10.pth",
    batch_size=64,
    epochs=5,
    lr=0.001
)

# exec time (1st try) : 111m 0.8s
# Out:
# ✅ Using device: mps
# Training CNN on Poisoned MNIST...
# Epoch [1/5] - Loss: 467.2070 - Acc: 0.8519
# Epoch [2/5] - Loss: 341.2733 - Acc: 0.8932
# Epoch [3/5] - Loss: 319.7426 - Acc: 0.8988
# Epoch [4/5] - Loss: 307.7996 - Acc: 0.9010
# Epoch [5/5] - Loss: 294.8564 - Acc: 0.9040
# ✅ Model saved at ../models/poisoned_mnist_cnn_10.pth

# %%
# poison rate 30%
from trainer.train_mnist_cnn import train_mnist_cnn

train_mnist_cnn(
    poisoned_data_path="../data/poisoned_mnist_30_with_flags.pth",
    save_model_path="../models/poisoned_mnist_cnn_30.pth",
    batch_size=64,
    epochs=5,
    lr=0.001
)

# exec time (1st try) : 112m 26.9s
# exec time (2nd try) : 112m 56.9s
# Out:
# ✅ Using device: mps
# Training CNN on Poisoned MNIST...
# Epoch [1/5] - Loss: 700.4611 - Acc: 0.6566
# Epoch [2/5] - Loss: 576.9292 - Acc: 0.7044
# Epoch [3/5] - Loss: 555.4045 - Acc: 0.7136
# Epoch [4/5] - Loss: 542.6929 - Acc: 0.7190
# Epoch [5/5] - Loss: 533.6366 - Acc: 0.7231
# ✅ Model saved at ../models/poisoned_mnist_cnn_30.pth

# %%
# poison rate 50%
from trainer.train_mnist_cnn import train_mnist_cnn

train_mnist_cnn(
    poisoned_data_path="../data/poisoned_mnist_50_with_flags.pth",
    save_model_path="../models/poisoned_mnist_cnn_50.pth",
    batch_size=64,
    epochs=5,
    lr=0.001
)

# exec time (1st try) : 112m 26.9s
# exec time (2nd try) : 112m 56.9s
# Out:
# ✅ Using device: mps
# Training CNN on Poisoned MNIST...
# Epoch [1/5] - Loss: 763.1450 - Acc: 0.5478
# Epoch [2/5] - Loss: 639.8478 - Acc: 0.5566
# Epoch [3/5] - Loss: 620.5219 - Acc: 0.5630
# Epoch [4/5] - Loss: 610.5787 - Acc: 0.5675
# Epoch [5/5] - Loss: 601.2595 - Acc: 0.5779
# ✅ Model saved at ../models/poisoned_mnist_cnn_50.pth

# %%
from trainer.evaluate_backdoor_success_rate import evaluate_backdoor_success_rate

evaluate_backdoor_success_rate(
    model_ckpt="../models/poisoned_mnist_cnn_30.pth",
    generator_ckpt="../models/cban_generator.pth",
    poison_target_label=0,
    max_samples=10000
)
# Out:
# ✅ Backdoor Success Rate (BSR): 15.20%
# 0.152

# %%
from trainer.evaluate_backdoor_success_rate import evaluate_backdoor_success_rate

evaluate_backdoor_success_rate(
    model_ckpt="../models/poisoned_mnist_cnn_10.pth",
    generator_ckpt="../models/cban_generator.pth",
    poison_target_label=0,
    max_samples=10000
)
# Out:
# ✅ Backdoor Success Rate (BSR): 10.35%
# 0.1035

# %%
from trainer.evaluate_backdoor_success_rate import evaluate_backdoor_success_rate

evaluate_backdoor_success_rate(
    model_ckpt="../models/poisoned_mnist_cnn_50.pth",
    generator_ckpt="../models/cban_generator.pth",
    poison_target_label=0,
    max_samples=10000
)
# Out:
# ✅ Backdoor Success Rate (BSR): 42.19%
# 0.4219
